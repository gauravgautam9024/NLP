# %% [markdown]
# ### Part of Speech (POS) Tagging
#
# POS Tagging ka matlab hota hai sentence ke har word ko uski grammatical category assign karna.
#
# Simple language me:
# 👉 Har word ko batana ki wo noun hai, verb hai, adjective hai, etc.
#
# 🔹 Example se samjhte hain:
#
# Sentence:
# 👉 "Rahul is playing cricket"
#
# POS Tagging:
#
# Rahul → Noun (naam hai)
# is → Verb (helping verb)
# playing → Verb (action)
# cricket → Noun (object)

# %%
from nltk import pos_tag
from nltk.tokenize import word_tokenize

text = input("Word input - ")
tokens = word_tokenize(text)

print(pos_tag(tokens))
# Out:
# Word input - Himanshu is a sweet boy
# [('Himanshu', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('sweet', 'JJ'), ('boy', 'NN')]

# %% [markdown]
# ### Table
# | Tag | Meaning         |
# | --- | --------------- |
# | NN  | Noun            |
# | NNP | Proper Noun     |
# | VB  | Verb            |
# | VBG | Verb (ing form) |
# | JJ  | Adjective       |
# | RB  | Adverb          |

# %% [markdown]
# ### Named Entity Recognition (NER)
#
# Named Entity Recognition (NER) NLP ka ek important task hai jisme hum text me se important entities (names) identify karte hain.
#
#  Simple words me:
#
# NER ka kaam hota hai text me se “kaun, kaha, kya” nikalna.
#
#
# Example
#
# Sentence:
#
# "Elon Musk is the CEO of Tesla and lives in the United States."
#
# 👉 NER Output:
#
# Elon Musk → Person
#
# Tesla → Organization
#
# United States → Location

# %% [markdown]
# ##
# | Entity Type | Meaning              | Example    |
# | ----------- | -------------------- | ---------- |
# | PERSON      | Insaan ka naam       | Elon Musk  |
# | ORG         | Company/Organization | Tesla      |
# | GPE         | Country/City         | USA, India |
# | DATE        | Date                 | 24 March   |
# | TIME        | Time                 | 10 AM      |
# | MONEY       | Paisa                | $100       |
# | PERCENT     | Percentage           | 50%        |

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\vinayak\appdata\local\programs\python\python310\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\vinayak\appdata\local\programs\python\python310\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\vinayak\appdata\local\programs\python\python310\lib\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\vinayak\appdata\local\programs\python\python310\lib\site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\vinayak\appdata\local\programs\python\python310\lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in c:\users\vinayak\appdata\local\programs\python\python310\lib\site-packages (from click->nltk) (0.4.5)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -illow (c:\users\vinayak\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\vinayak\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\vinayak\appdata\local\programs\python\python310\lib\site-packages)

# %%
import nltk

nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\VINAYAK\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\VINAYAK\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
import nltk

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\VINAYAK\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\VINAYAK\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\VINAYAK\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\VINAYAK\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %% [markdown]
# ### NER ka Use Kaha Hota Hai?
# 📰 News analysis
# 🤖 Chatbots
# 📊 Resume parsing
# 🔍 Search engines
# 💼 Business analytics

# %%
import nltk
from nltk import word_tokenize, pos_tag, ne_chunk

# %%
text = input("Enter the text")

# Step 1: Tokenize
tokens = word_tokenize(text)

# Step 2: POS Tagging
tags = pos_tag(tokens)

# Step 3: NER
ner = ne_chunk(tags)
# Out:
# Enter the textPutin is the President of Russia

# %%
print(ner)
# Out:
# (S
#   (PERSON Putin/NNP)
#   is/VBZ
#   the/DT
#   President/NNP
#   of/IN
#   (GPE Russia/NNP))

# %%
print(tags)
# Out:
# [('Putin', 'NNP'), ('is', 'VBZ'), ('the', 'DT'), ('President', 'NNP'), ('of', 'IN'), ('Russia', 'NNP')]

# %% [markdown]
# ## Frequency Distribution

# %%
from nltk.probability import FreqDist
from nltk.tokenize import word_tokenize

text = input("Enter the input - ")

tokens = word_tokenize(text)

fd = FreqDist(tokens)

print(fd)
# Out:
# Enter the input - Frequency distribution is a fundamental concept in natural language processing that helps in analyzing how often words appear in a given text. It allows us to identify the most common and least common words, making it easier to understand the overall theme or pattern of the data. By counting word occurrences, we can filter important keywords and remove unnecessary ones like stopwords. This technique is widely used in tasks such as text analysis, sentiment analysis, and keyword extraction. Frequency distribution also helps in creating visualizations like word clouds, which provide a clear representation of frequently used terms in a dataset.
# <FreqDist with 77 samples and 110 outcomes>

# %%
print(fd.most_common(6))
# Out:
# [('in', 6), ('.', 5), (',', 5), ('a', 4), ('the', 3), ('and', 3)]

# %% [markdown]
# ### N-Gram
#
# words ke groups (sequence) banana
#
#
# | Type    | Meaning | Example          |
# | ------- | ------- | ---------------- |
# | Unigram | 1 word  | I, love, NLP     |
# | Bigram  | 2 words | I love, love NLP |
# | Trigram | 3 words | I love NLP       |
#
#
#
#
# Example
#
# Sentence:
#
# "I love NLP"
#
#  Output:
#
# Unigram → I, love, NLP
# Bigram → (I love), (love NLP)
# Trigram → (I love NLP)

# %%
from nltk.util import ngrams
from nltk.tokenize import word_tokenize

text =input("Enter the input -  ")
tokens = word_tokenize(text)

# Bigrams
bigrams = list(ngrams(tokens, 2))
print(bigrams)
# Out:
# Enter the input -  Frequency distribution is a fundamental concept in natural language processing that helps in analyzing how often words appear in a given text. It allows us to identify the most common and least common words, making it easier to understand the overall theme or pattern of the data. By counting word occurrences, we can filter important keywords and remove unnecessary ones like stopwords. This technique is widely used in tasks such as text analysis, sentiment analysis, and keyword extraction. Frequency distribution also helps in creating visualizations like word clouds, which provide a clear representation of frequently used terms in a dataset.
# [('Frequency', 'distribution'), ('distribution', 'is'), ('is', 'a'), ('a', 'fundamental'), ('fundamental', 'concept'), ('concept', 'in'), ('in', 'natural'), ('natural', 'language'), ('language', 'processing'), ('processing', 'that'), ('that', 'helps'), ('helps', 'in'), ('in', 'analyzing'), ('analyzing', 'how'), ('how', 'often'), ('often', 'words'), ('words', 'appear'), ('appear', 'in'), ('in', 'a'), ('a', 'given'), ('given', 'text'), ('text', '.'), ('.', 'It'), ('It', 'allows'), ('allows', 'us'), ('us', 'to'), ('to', 'identify'), ('identify', 'the'), ('the', 'most'), ('most', 'common'), ('common', 'and'), ('and', 'least'), ('least', 'common'), ('common', 'words'), ('words', ','), (',', 'making'), ('making', 'it'), ('it', 'easier'), ('easier', 'to'), ('to', 'understand'), ('understand', 'the'), ('the', 'overall'), ('overall', 'theme'), ('theme', 'or'), ('or', 'pattern'), ('pattern', 'of'), ('of', 'the'), ('the', 'data'), ('data', '.'), ('.', 'By'), ('By', 'counting'), ('counting', 'word'), ('word', 'occurrences'), ('occurrences', ','), (',', 'we'), ('we', 'can'), ('can', 'filter'), ('filter', 'important'), ('important', 'keywords'), ('keywords', 'and'), ('and', 'remove'), ('remove', 'unnecessary'), ('unnecessary', 'ones'), ('ones', 'like'), ('like', 'stopwords'), ('stopwords', '.'), ('.', 'This'), ('This', 'technique'), ('technique', 'is'), ('is', 'widely'), ('widely', 'used'), ('used', 'in'), ('in', 'tasks'), ('tasks', 'such'), ('such', 'as'), ('as', 'text'), ('text', 'analysis'), ('analysis', ','), (',', 'sentiment'), ('sentiment', 'analysis'), ('analysis', ','), (',', 'and'), ('and', 'keyword'), ('keyword', 'extraction'), ('extraction', '.'), ('.', 'Frequency'), ('Frequency', 'distribution'), ('distribution', 'also'), ('also', 'helps'), ('helps', 'in'), ('in', 'creating'), ('creating', 'visualizations'), ('visualizations', 'like'), ('like', 'word'), ('word', 'clouds'), ('clouds', ','), (',', 'which'), ('which', 'provide'), ('provide', 'a'), ('a', 'clear'), ('clear', 'representation'), ('representation', 'of'), ('of', 'frequently'), ('frequently', 'used'), ('used', 'terms'), ('terms', 'in'), ('in', 'a'), ('a', 'dataset'), ('dataset', '.')]

# %% [markdown]
# ## WordNet (Synonyms & Antonyms)
#
#
# WordNet NLTK ka ek lexical database (dictionary) hai jisme words ke:
#
# Synonyms (same meaning)
#
#
# Antonyms (opposite meaning)
#
#
# Definitions
#
#
# Relationships
#
#
# store hote hain
#
#
# Word: good
#
# Synonyms → good, excellent, nice
# Antonyms → bad

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\VINAYAK\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#Synonyms

from nltk.corpus import wordnet

synsets = wordnet.synsets("excellent")

for syn in synsets:
    for lemma in syn.lemmas():
        print(lemma.name())
# Out:
# excellent
# first-class
# fantabulous
# splendid

# %%
#Antonyms (Opposite Meaning)
from nltk.corpus import wordnet

word = "good"
synsets = wordnet.synsets(word)

antonyms = []

for syn in synsets:
    for lemma in syn.lemmas():
        if lemma.antonyms():
            antonyms.append(lemma.antonyms()[0].name())

print(set(antonyms))
# Out:
# {'evil', 'badness', 'ill', 'bad', 'evilness'}

# %%
# meaning 
from nltk.corpus import wordnet

syn = wordnet.synsets("work")[0]
print(syn.definition())
# Out:
# activity directed toward making or doing something

# %% [markdown]
# #### Lemmas kya hote hain?
#
# 👉 Lemma = word ka base form / dictionary form
#
# Example:
#
# running → run
# better → good
#
# | Term     | Meaning                      |
# | -------- | ---------------------------- |
# | Synset   | Same meaning words ka group  |
# | Lemma    | Word ka base form            |
# | Hypernym | General word (animal → dog)  |
# | Hyponym  | Specific word (dog → animal) |

# %% [markdown]
# ### Parsing (Grammar Structure)
# Parsing NLP ka ek process hai jisme hum sentence ka grammar structure (structure/relationship) samajhte hain.
#
#  Simple words me:
#
# Parsing batata hai sentence me kaun subject hai, kaun verb hai, kaun object hai
#
#
# Example Sentence
#
# "I eat apple"
#
#  Parsing structure:
#
# I → Subject (NP – Noun Phrase)
#
#
# eat → Verb (VP – Verb Phrase)
#
#
# apple → Object
#
#
# | Term | Meaning     |
# | ---- | ----------- |
# | S    | Sentence    |
# | NP   | Noun Phrase |
# | VP   | Verb Phrase |
# | V    | Verb        |

# %%
import nltk

grammar = nltk.CFG.fromstring("""
S -> NP VP
NP -> 'I' | 'apple'
VP -> V NP
V -> 'eat'
""")

# %%
parser = nltk.ChartParser(grammar)

sentence = ["I", "eat", "apple"]

for tree in parser.parse(sentence):
    print(tree)
# Out:
# (S (NP I) (VP (V eat) (NP apple)))
